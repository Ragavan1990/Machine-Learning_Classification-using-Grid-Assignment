# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[479], line 2
#       1 # Reading the Dataset
# ----> 2 dataset = pd.read_csv('CKD.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
dataset.head(399)

# %%
dataset

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset

# %%
dataset.columns

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]} 



grid = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1') 
   
# fitting the model for grid search 
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Ragavan.L\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Ragavan.L\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Ragavan.L\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003125  6.250286e-03         0.000000    0.000000e+00
# 1        0.009375  7.654695e-03         0.000000    0.000000e+00
# 2        0.069783  7.955119e-03         0.022252    5.493951e-03
# 3        0.609206  9.847520e-03         0.031252    1.454158e-06
# 4        0.062502  9.172146e-07         0.015626    1.055524e-06
# 5        0.606544  1.545676e-02         0.034377    6.249070e-03
# 6        0.000000  0.000000e+00         0.000000    0.000000e+00
# 7        0.000000  0.000000e+00         0.000000    0.000000e+00
# 8        0.068754  7.654130e-03         0.012502    6.250858e-03
# 9        0.625557  9.890664e-03         0.031253    1.386932e-06
# 10       0.065626  6.251192e-03         0.015627    7.629395e-07
# 11       0.587553  7.622715e-03         0.031249    8.421228e-05
#
#    param_criterion param_max_features  param_n_estimators  \
# 0             gini               auto                  10
# ...

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 100}: 0.9849624060150376

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[50  1]
#  [ 1 81]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        51
#            1       0.99      0.99      0.99        82
#
#     accuracy                           0.98       133
#    macro avg       0.98      0.98      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %%
table_pr=pd.DataFrame()

# %%
print(X_test)
# Out:
#            age     bp   al   su         bgr    bu   sc         sod       pot  \
# 132  46.000000   70.0  0.0  0.0  100.000000  47.0  0.5  142.000000  3.500000
# 309  66.000000   90.0  2.0  0.0  153.000000  76.0  3.3  137.528754  4.627244
# 334  69.000000   70.0  0.0  0.0   83.000000  42.0  1.2  139.000000  3.700000
# 196  55.000000  100.0  1.0  4.0  297.000000  53.0  2.8  139.000000  4.500000
# 246  60.000000   90.0  2.0  0.0  105.000000  53.0  2.3  136.000000  5.200000
# ..         ...    ...  ...  ...         ...   ...  ...         ...       ...
# 349  71.000000   70.0  0.0  0.0   81.000000  18.0  0.8  145.000000  5.000000
# 168  50.000000   80.0  0.0  0.0  137.000000  46.0  0.8  139.000000  5.000000
# 150  48.000000  100.0  0.0  0.0  103.000000  79.0  5.3  135.000000  6.300000
# 392  51.492308   60.0  3.0  0.0  148.112676  34.0  1.2  137.528754  4.627244
# 66   34.000000   60.0  0.0  0.0   91.000000  49.0  1.2  135.000000  4.500000
#
# ...

# %%
table_pr['age']=X_test["age"]
table_pr['bp']=X_test["bp"]
table_pr['al']=X_test["al"]
table_pr['su']=y_test
table_pr['bgr']=grid_predictions
table_pr['bu']=X_test["bu"]
table_pr['sc']=X_test["sc"]
table_pr['sod']=X_test["sod"]
table_pr['pot']=y_test
table_pr['hrmo']=grid_predictions
table_pr['pcv']=X_test["pcv"]
table_pr['wc']=X_test["wc"]
table_pr['sg_b']=X_test["sg_b"]
table_pr['sg_c']=y_test
table_pr['sg_d']=grid_predictions
table_pr['sg_e']=X_test["sg_e"]
table_pr['rbc_normal']=X_test["rbc_normal"]
table_pr['pc_normal']=X_test["pc_normal"]
table_pr['pcc_present']=y_test
table_pr['ba_present']=grid_predictions
table_pr['htn_yes']=X_test["htn_yes"]
table_pr['dm_yes']=X_test["dm_yes"]
table_pr['cad_yes']=X_test["cad_yes"]
table_pr['appet_yes']=y_test
table_pr['pe_yes']=grid_predictions

# %%
#table_pr.head(399)

# %%
#table_pr.to_csv("ckd.csv",index=False)

# %%
#dataset['']
#dataset['Predicted']=grid_predictions

# %%
#table_pr.to_csv("cm.csv",index=False)

# %%
age=float(input("Age:"))
bp=float(input("BP:"))
al=float(input("AL:"))
su=int(input("SU:"))
bgr=int(input("BGR:"))
bu=int(input("BU:"))
sc=int(input("SC:"))
sod=int(input("SOD:"))
pot=int(input("POT:"))
hrmo=int(input("HRMO:"))
wc=int(input("WC:"))
rc=int(input("rc:"))
sg_b=int(input("sg_b:"))
sg_c=int(input("sg_c:"))
sg_d=int(input("sg_d:"))
sg_e=int(input("sg_e:"))
rbc_normal=int(input("rbc_normal:"))
pcc_present=int(input("pcc_present:"))
ba_present=int(input("ba_present:"))
htn_yes=int(input("htn_yes:"))
dm_yes=int(input("dm_yes:"))
appet_yes=int(input("appet_yes:"))
pe_yes=int(input("pe_yes:"))
ane_yes=int(input("ane_yes:"))
pcv=int(input("pcv:"))
pc_normal=int(input("pcv:"))
cad_yes=int(input("pcv:"))
# Out:
# Age: 1
# BP: 2
# AL: 3
# SU: 4
# BGR: 5
# BU: 6
# SC: 7
# SOD: 8
# POT: 9
# HRMO: 10
# WC: 11
# rc: 12
# sg_b: 13
# sg_c: 14
# sg_d: 15
# sg_e: 16
# rbc_normal: 17
# pcc_present: 18
# ba_present: 19
# htn_yes: 20
# dm_yes: 21
# appet_yes: 22
# pe_yes: 23
# ane_yes: 24
# pcv: 25
# pcv: 26
# pcv: 27

# %%
Future_Prediction=grid.predict([[age,bp,al,su,bgr,bu,sc,sod,pot,hrmo,wc,rc,sg_b,sg_c,sg_d,sg_e,rbc_normal,pcc_present,ba_present,htn_yes,dm_yes,appet_yes,pe_yes,ane_yes,pcv,pc_normal,cad_yes]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
